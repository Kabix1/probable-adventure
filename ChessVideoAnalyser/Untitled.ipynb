# %%
from FEN import analyser

fen = analyser()
fen.run()
# Out:
# ../downloads/images/digital_board_231s.png
# 860

# %%
# Out:
# ['../data/templates/white_rook1.png', '../data/templates/white_rook2.png']
# ['../data/templates/white_knight2.png', '../data/templates/white_knight1.png']
# ['../data/templates/white_bishop1.png', '../data/templates/white_bishop2.png']
# ['../data/templates/white_king1.png']
# ['../data/templates/white_queen1.png']
# ['../data/templates/white_pawn2.png', '../data/templates/white_pawn1.png']
# ['../data/templates/black_rook1.png', '../data/templates/black_rook2.png']
# ['../data/templates/black_knight2.png', '../data/templates/black_knight1.png']
# ['../data/templates/black_bishop1.png', '../data/templates/black_bishop2.png']
# ['../data/templates/black_king1.png']
# ['../data/templates/black_queen1.png']
# ['../data/templates/black_pawn2.png', '../data/templates/black_pawn1.png']

# %%
fen.test_FEN()
# Out:
# Error in digital_board_24s, threshold of B too low
# Error in digital_board_25s, threshold of P too low
# Error in digital_board_29s, threshold of B too low
# Error in digital_board_30s, threshold of P too low
# Error in digital_board_32s, threshold of B too low
# Error in digital_board_35s, threshold of B too low
# Error in digital_board_36s, threshold of P too low
# Error in digital_board_46s, threshold of r too low
# Error in digital_board_47s, threshold of R too low
# Error in digital_board_52s, threshold of r too low
# Error in digital_board_56s, threshold of B too low
# Error in digital_board_57s, threshold of P too low
# Error in digital_board_57s, threshold of R too low
# Error in digital_board_61s, threshold of B too low
# Error in digital_board_62s, threshold of b too low
# Error in digital_board_62s, threshold of P too low
# Error in digital_board_67s, threshold of r too low
# Error in digital_board_67s, threshold of B too low
# ...
